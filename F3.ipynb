# %%
import pandas as pd
import re

# %%
# 1. Cargar los datos
df = pd.read_excel("DatosTecnicaTurboshop.xlsx", sheet_name="F3")
df.head(20)
# Out:
#             Codigo                                             Nombre  \
# 0        2996724-5  RADIADOR MT L300 2.4 92-98+2.0-2.5 96-11 T/M C...
# 1        041010021  ACEITE 75W90 OPTIMUS DIF+CAJA T/M 1LT SEMISIN 648
# 2     OK7AA-52-910                       PTA FRONTAL LH 2005> GENUINO
# 3           280085                         PRENSA EMB HY SON EF VALEO
# 4      71911-43900                         PTA FRONTAL 98-2004 LH VAN
# 5      21443-33004                RET CIG TRAS HY H-100 80*96*9 KOREA
# 6         24535532                               MANILLA N300 ASIDERO
# 7        213109151               RADIADOR SS ACTYON 2.0 07-11 T/M GEN
# 8         0016758D       FOTO TRAS KIA CARENS 07-11 (C/DETALLE) CHINA
# 9      54501-FD000                     BANDEJA KIA RIO 03-05 RH KOREA
# 10  0016758DETALLE    FOCO TRAS KIA CARENS 07-11 RH (C/DETALLE) CHINA
# 11   0K72A-28-830B           BUJE BARRA TENSORA TRAS 98-06 (2X BARRA)
# ...

# %%
def expand_years(text):
    matches = re.findall(r"(\\d{2,4})\\s*[-–>]\\s*(\\d{2,4})", text)
    years = []
    for start, end in matches:
        start = int(start) if len(start) == 4 else int("20" + start) if int(start) < 50 else int("19" + start)
        end = int(end) if len(end) == 4 else int("20" + end) if int(end) < 50 else int("19" + end)
        years += list(range(start, end + 1))
    return years

# %%
rows = []

for _, row in df.iterrows():
    codigo = str(row[0])
    descripcion = str(row[1]) + " " + str(row[2])
    
    # Buscamos años en formato rango
    años = expand_years(descripcion)
    
    # Cilindrada
    cilindrada = re.search(r"(\\d\\.\\d)", descripcion)
    cilindrada = cilindrada.group(1) if cilindrada else None

    # Marca y modelo potenciales (puedes extender esto)
    marcas_modelos = re.findall(
        r"(HYUNDAI|KIA|SSANGYONG|MITSUBISHI|TOYOTA|MAZDA|CHEVROLET|NISSAN|LANCER|CARENS|ACTYON|SONATA|ELANTRA|OPTIMA|B2500|RIO|H100|TERRACAN|GALANT|MORNING|FRONTIER|KORANDO|PREGIO|ASX)",
        descripcion.upper()
    )
    
    for año in años:
        rows.append({
            "codigo": codigo,
            "descripcion": descripcion,
            "marca_modelo": ", ".join(set(marcas_modelos)),
            "año": año,
            "cilindrada": cilindrada
        })
# Out:
# /var/folders/0t/_qm975t16jj4mgcwr01mv1fc0000gn/T/ipykernel_40296/3596206553.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   codigo = str(row[0])
# /var/folders/0t/_qm975t16jj4mgcwr01mv1fc0000gn/T/ipykernel_40296/3596206553.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   descripcion = str(row[1]) + " " + str(row[2])
