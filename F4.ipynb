# %%
import pandas as pd
import re
from unidecode import unidecode
from collections import defaultdict

# %%
# Ruta del archivo (ajusta si es necesario)
ruta_archivo = "DatosTecnicaTurboshop.xlsx"

# Cargar el archivo Excel y ver los nombres de las hojas
xls = pd.ExcelFile(ruta_archivo)
print("Hojas disponibles:", xls.sheet_names)
# Out:
# Hojas disponibles: ['F1', 'F2', 'F3', 'F4']

# %%
# Cargar todas las hojas en un diccionario
hojas = {nombre: xls.parse(nombre) for nombre in xls.sheet_names}

# Mostrar las primeras filas de cada hoja
for nombre, df in hojas.items():
    print(f"\n--- {nombre} ---")
    display(df.head())
# Out:
# --- F1 ---
#         Codigo                                             Nombre  \
# 0  T181-1745-2  Cadena de Distribucion, larga, doble, 94 eslab...
# 1  T181-1746-0  Cadena Larga Distribucion Toyota Corolla 1600C...
# 2  T181-2826-8  Cadena de Distribucion, Superior, 84 eslabones...
# 3  T181-2825-K                 Cadena Distribucion Chevrolet N300
# 4  T181-3979-0       Cadena de Distribucion, 90 Eslabones, simple
#
#    Aplicaciones
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# --- F2 ---
#     Codigo                                  Nombre  \
# 0  9075788  CALIPER DELANTERO IZQUIERDO (NORTARGE)
# 1  9075789    CALIPER DELANTERO DERECHO (NORTARGE)
# 2  9075789     CALIPER DELANTERO DERECHO (UXCLENT)
# 3  9075910                  FILTRO POLEN (KENDALL)
# 4  9114603            SENSOR VELOCIDAD (NETMOTORS)
#
#                                         Aplicaciones
# 0                                 SAIL 1.4 2011/2018
# 1                                 SAIL 1.4 2011/2018
# 2                                 SAIL 1.4 2011/2018
# 3                             SAIL 1.4 1.5 2010/2021
# 4  CORSA 1.4 1.6 1993/1998-ASTRA 1.4 1.6 1992/199...
# --- F3 ---
#          Codigo                                             Nombre  \
# 0     2996724-5  RADIADOR MT L300 2.4 92-98+2.0-2.5 96-11 T/M C...
# 1     041010021  ACEITE 75W90 OPTIMUS DIF+CAJA T/M 1LT SEMISIN 648
# 2  OK7AA-52-910                       PTA FRONTAL LH 2005> GENUINO
# 3        280085                         PRENSA EMB HY SON EF VALEO
# 4   71911-43900                         PTA FRONTAL 98-2004 LH VAN
#
#    Aplicaciones
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# --- F4 ---
#   PATENTE PATENTE_DV           TIPO      MARCA                MODELO  AÑO_FAB  \
# 0  LTXZ55          4      AUTOMOVIL    HYUNDAI  GRAND I10 BA PE HB 1     2020
# 1  LTXZ80          5      CAMIONETA  SSANGYONG   MUSSO GRAND 4X4 2.2     2020
# 2  LTXZ83          K  STATION WAGON       FORD   EXPLORER XLT 3.5 AT     2020
# 3  LTYB45          1      AUTOMOVIL        KIA         SOLUTO LX 1.4     2020
# 4  LTYB83          4      CAMIONETA    RENAULT     OROCH PICK UP 1.6     2020
#
#       COLOR
# 0  PLATEADO
# 1      GRIS
# 2    BLANCO
# 3  PLATEADO
# 4    BLANCO

# %%
# 1. Cargar los datos
df = pd.read_excel("DatosTecnicaTurboshop.xlsx", sheet_name="F4")
df['MODELO'] = df['MODELO'].astype(str).str.upper().str.strip()

# %%
# 2. Función mejorada para extraer tipo de vehículo (con énfasis en HATCHBACK)
def extraer_tipo_vehiculo(texto):
    # Ordenamos los patrones de más específico a menos específico
    patrones_tipo = [
        (r'\bHATCH\s?BACK\b', 'HATCHBACK'),  # Primero este para captar "HATCH BACK"
        (r'\bSTATION\sWAGON\b', 'SW'),
        (r'\bPICK\s?UP\b', 'PICKUP'),
        (r'\bMINIBUS\b', 'MINIBUS'),
        (r'\bSUV\b', 'SUV'),
        (r'\bSEDAN\b', 'SEDAN'),
        (r'\bCOUPE\b', 'COUPE'),
        (r'\bHB\b', 'HATCHBACK'),  # HB como abreviatura
        (r'\b5P\b', '5P'),      # 3 puertas
        (r'\b3P\b', 'HATCHBACK'),      # 3 puertas
        (r'\bHATCH\b', 'HATCHBACK') # Solo "HATCH"
    ]
    
    for patron, tipo in patrones_tipo:
        if re.search(patron, texto, flags=re.IGNORECASE):
            # Reemplazamos todas las ocurrencias
            texto = re.sub(patron, '', texto, flags=re.IGNORECASE).strip()
            return tipo, texto
    return None, texto

# %%
# 3. Función de extracción completa
def extraer_detalles_modelo(texto):
    detalles = {
        'texto_original': texto,
        'cilindrada': None,
        'traccion': None,
        'transmision': None,
        'tipo_vehiculo': None,
        'modelo_base': None,
        'version': None
    }
    
    if not isinstance(texto, str) or texto == 'NAN':
        return detalles
    
    texto_limpio = texto
    
    # Primero extraer el tipo de vehículo (ahora con prioridad)
    tipo, texto_limpio = extraer_tipo_vehiculo(texto_limpio)
    detalles['tipo_vehiculo'] = tipo
    
    # Luego extraer otros componentes técnicos
    cilindrada_match = re.search(r'\b(\d\.\d)\b', texto_limpio)
    if cilindrada_match:
        detalles['cilindrada'] = cilindrada_match.group(1)
        texto_limpio = texto_limpio.replace(detalles['cilindrada'], '')
    
    traccion_match = re.search(r'\b([24][Xx][24])\b', texto_limpio)
    if traccion_match:
        detalles['traccion'] = traccion_match.group(1).upper()
        texto_limpio = texto_limpio.replace(traccion_match.group(1), '')
    
    transmision_match = re.search(r'\b(AUT|AT|MT|CVT)\b', texto_limpio)
    if transmision_match:
        detalles['transmision'] = transmision_match.group(1)
        texto_limpio = texto_limpio.replace(detalles['transmision'], '')
    
    # Limpieza final
    texto_limpio = re.sub(r'[^A-Z0-9 ]', '', texto_limpio)
    texto_limpio = re.sub(r'\s+', ' ', texto_limpio).strip()
    
    # Extracción de modelo base y versión según reglas especificadas
    palabras = texto_limpio.split()
    
    if len(palabras) > 1:
        detalles['modelo_base'] = palabras[0]
        detalles['version'] = ' '.join(palabras[1:])
    elif len(palabras) == 1:
        detalles['modelo_base'] = palabras[0]
        detalles['version'] = ''
    else:
        detalles['modelo_base'] = ''
        detalles['version'] = ''

    
    return detalles

# %%
# 3. Aplicar la función y crear nuevas columnas
detalles = pd.DataFrame(df['MODELO'].apply(extraer_detalles_modelo).tolist())
df = pd.concat([df, detalles], axis=1)

# %%
df
# Out:
#    PATENTE PATENTE_DV           TIPO       MARCA                MODELO  \
# 0   LTXZ55          4      AUTOMOVIL     HYUNDAI  GRAND I10 BA PE HB 1
# 1   LTXZ80          5      CAMIONETA   SSANGYONG   MUSSO GRAND 4X4 2.2
# 2   LTXZ83          K  STATION WAGON        FORD   EXPLORER XLT 3.5 AT
# 3   LTYB45          1      AUTOMOVIL         KIA         SOLUTO LX 1.4
# 4   LTYB83          4      CAMIONETA     RENAULT     OROCH PICK UP 1.6
# 5   LTYB93          1      CAMIONETA  MITSUBISHI   L200 WORK CR WF 2.4
# 6   LTYC15          6  STATION WAGON     HYUNDAI   CRETA GS PE 1.6 AUT
# 7   LTYC19          9  STATION WAGON          MG             ZS 5P 1.5
# 8   LTYC39          3  STATION WAGON   SSANGYONG        TIVOLI 1.6 AUT
# 9   LTYC41          5      AUTOMOVIL   CHEVROLET              SAIL 1.5
# 10  LTYC48          2      AUTOMOVIL          MG      3 HATCH BACK 1.5
# 11  LTYC52          0  STATION WAGON        JEEP  CHEROKEE LONGITUDE F
# 12  LTYC65          2  STATION WAGON          DS   3 CROSSBACK HDI 100
# 13  LTYC67          9      AUTOMOVIL          MG      3 HATCH BACK 1.5
# 14  LTYC79          2      AUTOMOVIL         BMW        118D HB 2.0 AT
# 15  LTYD65          9      CAMIONETA   CHEVROLET  COLORADO DCAB 4X4 2.
# 16  LTYD66          7      AUTOMOVIL       MAZDA      3 HATCH BACK 2.0
# 17  LTYD67          5      AUTOMOVIL   CHEVROLET              SAIL 1.5
# 18  LTYD83          7  STATION WAGON     HYUNDAI         TUCSON TL 2.0
# 19  LTYF10          8      AUTOMOVIL   CHEVROLET              SAIL 1.5
# 20  LTYF12          4      AUTOMOVIL   CHEVROLET              SAIL 1.5
# 21  LTYF80          9      CAMIONETA     HYUNDAI    PORTER II DOHC 2.5
# 22  LTYG97          K  STATION WAGON          MG             ZS 1.5 AT
# 23  LTYG98          8  STATION WAGON          MG             ZS 5P 1.5
# 24  LTYH11          9      CAMIONETA  VOLKSWAGEN     SAVEIRO D CAB 1.6
# 25  LTYH23          2  STATION WAGON      NISSAN  PATHFINDER CVT 3.5 A
# 26  LTYH42          9      CAMIONETA      NISSAN  NP300 NAVARA DCAB 4X
# 27  LTYH69          0  STATION WAGON         BMW  X4 XDRIVE 20I 4X4 2.
# 28  LTYJ49          2      CAMIONETA  MITSUBISHI   L200 KATANA CRT 4X4
# 29  LTYJ63          8      CAMIONETA  MITSUBISHI   L200 KATANA CRT 4X4
# 30  LTYJ67          0      AUTOMOVIL          MG      3 HATCH BACK 1.5
# 31  LTYJ84          0      CAMIONETA   SSANGYONG   MUSSO GRAND 4X4 2.2
# 32  LTYJ86          7      AUTOMOVIL   CHEVROLET              SAIL 1.5
# 33  LTYK30          8      AUTOMOVIL   CHEVROLET  SPARK GT HB DOHC 1.2
# 34  LTYK49          9  STATION WAGON      SUBARU  FORESTER CVT 4X4 2.0
# 35  LTYL19          3      AUTOMOVIL      SUZUKI     BALENO GLS HB 1.4
# 36  LTYL38          K  STATION WAGON      SUZUKI     SCROSS II GLX 1.6
# 37  LTYL45          2        MINIBUS         JAC     NEW REFINE M4 2.0
# 38  LTYL49          5  STATION WAGON         JAC             S3 CE 1.6
# 39  LTYL61          4  STATION WAGON  GREAT WALL              3 SR 2.0
# 40  LTYP25          0  STATION WAGON  GREAT WALL              3 LE 2.0
# 41  LTYP56          0      AUTOMOVIL        FIAT       UNO WAY EVO 1.4
# 42  LTYP73          0      CAMIONETA   SSANGYONG       GRAND MUSSO 2.2
# 43  LTYR17          2      AUTOMOVIL      SUZUKI    DZIRE GL SPORT 1.2
# 44  LTYR27          K      AUTOMOVIL       MAZDA             3 2.0 AUT
# 45  LTYS36          5      AUTOMOVIL     HYUNDAI   GRAND I10 BA GLS HB
# 46  LTYS91          8  STATION WAGON     HYUNDAI     TUCSON TL 4X4 2.0
# 47  LTYT72          8  STATION WAGON      NISSAN       X TRAIL 2.5 AUT
#
#     AÑO_FAB     COLOR        texto_original cilindrada traccion transmision  \
# 0      2020  PLATEADO  GRAND I10 BA PE HB 1       None     None        None
# 1      2020      GRIS   MUSSO GRAND 4X4 2.2        2.2      4X4        None
# 2      2020    BLANCO   EXPLORER XLT 3.5 AT        3.5     None          AT
# 3      2020  PLATEADO         SOLUTO LX 1.4        1.4     None        None
# 4      2020    BLANCO     OROCH PICK UP 1.6        1.6     None        None
# 5      2020      GRIS   L200 WORK CR WF 2.4        2.4     None        None
# 6      2020      GRIS   CRETA GS PE 1.6 AUT        1.6     None         AUT
# 7      2020    BLANCO             ZS 5P 1.5        1.5     None        None
# 8      2019  PLATEADO        TIVOLI 1.6 AUT        1.6     None         AUT
# 9      2020      CAFE              SAIL 1.5        1.5     None        None
# 10     2020      ROJO      3 HATCH BACK 1.5        1.5     None        None
# 11     2020     NEGRO  CHEROKEE LONGITUDE F       None     None        None
# 12     2020      AZUL   3 CROSSBACK HDI 100       None     None        None
# 13     2020    BLANCO      3 HATCH BACK 1.5        1.5     None        None
# 14     2020    BLANCO        118D HB 2.0 AT        2.0     None          AT
# 15     2020      AZUL  COLORADO DCAB 4X4 2.       None      4X4        None
# 16     2020      GRIS      3 HATCH BACK 2.0        2.0     None        None
# 17     2020  PLATEADO              SAIL 1.5        1.5     None        None
# 18     2020      GRIS         TUCSON TL 2.0        2.0     None        None
# 19     2020      ROJO              SAIL 1.5        1.5     None        None
# 20     2020      AZUL              SAIL 1.5        1.5     None        None
# 21     2020    BLANCO    PORTER II DOHC 2.5        2.5     None        None
# 22     2020      ROJO             ZS 1.5 AT        1.5     None          AT
# 23     2020      ROJO             ZS 5P 1.5        1.5     None        None
# 24     2020    BLANCO     SAVEIRO D CAB 1.6        1.6     None        None
# 25     2020      GRIS  PATHFINDER CVT 3.5 A        3.5     None         CVT
# 26     2020      ROJO  NP300 NAVARA DCAB 4X       None     None        None
# 27     2020      AZUL  X4 XDRIVE 20I 4X4 2.       None      4X4        None
# 28     2020      ROJO   L200 KATANA CRT 4X4       None      4X4        None
# 29     2020      ROJO   L200 KATANA CRT 4X4       None      4X4        None
# 30     2020      AZUL      3 HATCH BACK 1.5        1.5     None        None
# 31     2020    BLANCO   MUSSO GRAND 4X4 2.2        2.2      4X4        None
# 32     2020      ROJO              SAIL 1.5        1.5     None        None
# 33     2020  PLATEADO  SPARK GT HB DOHC 1.2        1.2     None        None
# 34     2020  PLATEADO  FORESTER CVT 4X4 2.0        2.0      4X4         CVT
# 35     2020      GRIS     BALENO GLS HB 1.4        1.4     None        None
# 36     2020    BLANCO     SCROSS II GLX 1.6        1.6     None        None
# 37     2020  PLATEADO     NEW REFINE M4 2.0        2.0     None        None
# 38     2020     NEGRO             S3 CE 1.6        1.6     None        None
# 39     2020      GRIS              3 SR 2.0        2.0     None        None
# 40     2020     NEGRO              3 LE 2.0        2.0     None        None
# 41     2020      GRIS       UNO WAY EVO 1.4        1.4     None        None
# 42     2020    BLANCO       GRAND MUSSO 2.2        2.2     None        None
# 43     2020  PLATEADO    DZIRE GL SPORT 1.2        1.2     None        None
# 44     2020      GRIS             3 2.0 AUT        2.0     None         AUT
# 45     2020      GRIS   GRAND I10 BA GLS HB       None     None        None
# 46     2020  PLATEADO     TUCSON TL 4X4 2.0        2.0      4X4        None
# 47     2020  PLATEADO       X TRAIL 2.5 AUT        2.5     None         AUT
#
#    tipo_vehiculo modelo_base            version
# 0      HATCHBACK       GRAND        I10 BA PE 1
# 1           None       MUSSO              GRAND
# 2           None    EXPLORER                XLT
# 3           None      SOLUTO                 LX
# 4         PICKUP       OROCH
# 5           None        L200         WORK CR WF
# 6           None       CRETA              GS PE
# 7             5P          ZS
# 8           None      TIVOLI
# 9           None        SAIL
# 10     HATCHBACK           3
# 11          None    CHEROKEE        LONGITUDE F
# 12          None           3  CROSSBACK HDI 100
# 13     HATCHBACK           3
# 14     HATCHBACK        118D
# 15          None    COLORADO             DCAB 2
# 16     HATCHBACK           3
# 17          None        SAIL
# 18          None      TUCSON                 TL
# 19          None        SAIL
# 20          None        SAIL
# 21          None      PORTER            II DOHC
# 22          None          ZS
# 23            5P          ZS
# 24          None     SAVEIRO              D CAB
# 25          None  PATHFINDER                  A
# 26          None       NP300     NAVARA DCAB 4X
# 27          None          X4       XDRIVE 20I 2
# 28          None        L200         KATANA CRT
# 29          None        L200         KATANA CRT
# 30     HATCHBACK           3
# 31          None       MUSSO              GRAND
# 32          None        SAIL
# 33     HATCHBACK       SPARK            GT DOHC
# 34          None    FORESTER
# 35     HATCHBACK      BALENO                GLS
# 36          None      SCROSS             II GLX
# 37          None         NEW          REFINE M4
# 38          None          S3                 CE
# 39          None           3                 SR
# 40          None           3                 LE
# 41          None         UNO            WAY EVO
# 42          None       GRAND              MUSSO
# 43          None       DZIRE           GL SPORT
# 44          None           3
# 45     HATCHBACK       GRAND         I10 BA GLS
# 46          None      TUCSON                 TL
# 47          None           X              TRAIL

# %%
# Diccionario de correcciones completas (modelo y versión)
correcciones_completas = {
    # HYUNDAI GRAND I10
    ('HYUNDAI', 'GRAND'): {
        'modelo': 'GRAND I10',
        'version': lambda x: x.replace('I10', '').strip()
    },
    
    # NISSAN X-TRAIL
    ('NISSAN', 'X'): {
        'modelo': 'X-TRAIL',
        'version': lambda x: x.replace('TRAIL', '').strip()
    },
    
    # JAC NEW REFINE
    ('JAC', 'NEW'): {
        'modelo': 'NEW REFINE',
        'version': lambda x: x.replace('REFINE', '').strip()
    },
    
    # NISSAN NP300 (unificar con NAVARA)
    ('NISSAN', 'NP300'): {
        'modelo': 'NAVARA',
        'version': lambda x: x.replace('NAVARA', '').strip()
    },
    
    ('SSANGYONG', 'GRAND'): {
        'modelo': 'MUSSO',
        'version': lambda x: x.replace('MUSSO', 'GRAND').strip()
    },
    
    # HYUNDAI GRAND I10 (caso alternativo)
    ('HYUNDAI', 'GRAND I10'): {
        'modelo': 'GRAND I10',
        'version': lambda x: x.replace('I10', '').strip()
    }
}

# Función para aplicar correcciones completas
def corregir_modelo_y_version(row):
    marca = row['MARCA']
    modelo_actual = row['modelo_base']
    version_actual = row['version']
    
    # Verificar si hay corrección para esta marca y modelo
    if (marca, modelo_actual) in correcciones_completas:
        correccion = correcciones_completas[(marca, modelo_actual)]
        nuevo_modelo = correccion['modelo']
        nueva_version = correccion['version'](version_actual)
        return pd.Series([nuevo_modelo, nueva_version])
    
    # Caso especial para GRAND I10 que aparece de dos formas
    if marca == 'HYUNDAI' and modelo_actual == 'GRAND' and 'I10' in version_actual:
        nuevo_modelo = 'GRAND I10'
        nueva_version = version_actual.replace('I10', '').strip()
        return pd.Series([nuevo_modelo, nueva_version])
    
    return pd.Series([row['modelo_base'], row['version']])

# Aplicar correcciones
df[['modelo_base_corregido', 'version_corregida']] = df.apply(corregir_modelo_y_version, axis=1)

# %%
df_4 = df[['MARCA', 'modelo_base_corregido', 'version_corregida', 'cilindrada', 'AÑO_FAB']]
df_4
# Out:
#          MARCA modelo_base_corregido  version_corregida cilindrada  AÑO_FAB
# 0      HYUNDAI             GRAND I10            BA PE 1       None     2020
# 1    SSANGYONG                 MUSSO              GRAND        2.2     2020
# 2         FORD              EXPLORER                XLT        3.5     2020
# 3          KIA                SOLUTO                 LX        1.4     2020
# 4      RENAULT                 OROCH                           1.6     2020
# 5   MITSUBISHI                  L200         WORK CR WF        2.4     2020
# 6      HYUNDAI                 CRETA              GS PE        1.6     2020
# 7           MG                    ZS                           1.5     2020
# 8    SSANGYONG                TIVOLI                           1.6     2019
# 9    CHEVROLET                  SAIL                           1.5     2020
# 10          MG                     3                           1.5     2020
# 11        JEEP              CHEROKEE        LONGITUDE F       None     2020
# 12          DS                     3  CROSSBACK HDI 100       None     2020
# 13          MG                     3                           1.5     2020
# 14         BMW                  118D                           2.0     2020
# 15   CHEVROLET              COLORADO             DCAB 2       None     2020
# 16       MAZDA                     3                           2.0     2020
# 17   CHEVROLET                  SAIL                           1.5     2020
# 18     HYUNDAI                TUCSON                 TL        2.0     2020
# 19   CHEVROLET                  SAIL                           1.5     2020
# 20   CHEVROLET                  SAIL                           1.5     2020
# 21     HYUNDAI                PORTER            II DOHC        2.5     2020
# 22          MG                    ZS                           1.5     2020
# 23          MG                    ZS                           1.5     2020
# 24  VOLKSWAGEN               SAVEIRO              D CAB        1.6     2020
# 25      NISSAN            PATHFINDER                  A        3.5     2020
# 26      NISSAN                NAVARA            DCAB 4X       None     2020
# 27         BMW                    X4       XDRIVE 20I 2       None     2020
# 28  MITSUBISHI                  L200         KATANA CRT       None     2020
# 29  MITSUBISHI                  L200         KATANA CRT       None     2020
# 30          MG                     3                           1.5     2020
# 31   SSANGYONG                 MUSSO              GRAND        2.2     2020
# 32   CHEVROLET                  SAIL                           1.5     2020
# 33   CHEVROLET                 SPARK            GT DOHC        1.2     2020
# 34      SUBARU              FORESTER                           2.0     2020
# 35      SUZUKI                BALENO                GLS        1.4     2020
# 36      SUZUKI                SCROSS             II GLX        1.6     2020
# 37         JAC            NEW REFINE                 M4        2.0     2020
# 38         JAC                    S3                 CE        1.6     2020
# 39  GREAT WALL                     3                 SR        2.0     2020
# 40  GREAT WALL                     3                 LE        2.0     2020
# 41        FIAT                   UNO            WAY EVO        1.4     2020
# 42   SSANGYONG                 MUSSO              GRAND        2.2     2020
# 43      SUZUKI                 DZIRE           GL SPORT        1.2     2020
# 44       MAZDA                     3                           2.0     2020
# 45     HYUNDAI             GRAND I10             BA GLS       None     2020
# 46     HYUNDAI                TUCSON                 TL        2.0     2020
# 47      NISSAN               X-TRAIL                           2.5     2020
